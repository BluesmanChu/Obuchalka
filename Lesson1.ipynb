# %% [markdown]
# # Заголовок 1 уровня
# ## заголовок 2 уровня

# %% [markdown]
# комменарий в виде текста

# %%
print ('Здравствуй, дивный новый мир')
# Out:
# Здравствуй, дивный новый мир

# %% [markdown]
# $$c = \sqrt(a^2 + b^2)$$

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([1,3,2,4,7,])

# %%
# процентная ставка
p = int(input ('Введи % '))
# капитализаций в год
f = int(input ('Введи количество начислений в год: '))
# сумма вклада
S = 200000
# срок вклада в годах
L = 5
# прибыль по вкладу

round(S*(1+p/(100*f))**(f*L)-S,2)
# Out:
# Введи % 8
# Введи количество начислений в год: 12
# 97969.14

# %%
round(200000*(1+8/(100*12))**(12*5)-200000, 2)
# Out:
# 97969.14
